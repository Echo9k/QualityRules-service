# %% [markdown]
# To process your rules file, accounting for similarities like different versions of rules (e.g., `DQRC0001` and `DQRC0001_01`) or semantically similar rules (e.g., `DQRC0074` and `DQRC0081`), the code needs additional steps:
#
# 1. **Preprocessing and Similarity Analysis:**
#    - Group rules with versioned IDs or highly similar logic.
#    - Use a combination of string similarity (e.g., Levenshtein distance) and semantic similarity (e.g., cosine similarity on embeddings).
# 2. **Rule Clustering:**
#    - Use text embeddings (via Sentence Transformers) to identify clusters of similar rules based on descriptions or code logic.

# %%
from pathlib import Path


path_root = Path.cwd()
while not (path_root / "data").exists():
    if path_root == path_root.parent:
        raise FileNotFoundError("Directory 'data' not found")
    path_root = path_root.parent

path_data = path_root / "data"

# %%
import pandas as pd
from sentence_transformers import SentenceTransformer
from sklearn.cluster import DBSCAN
from sklearn.metrics.pairwise import cosine_similarity
import re

# %%
pd.read_excel(path_root / 'data/processed/Bank_of_Rules-refractored.xlsx')
# Out:
#           RuleID                                               Code  \
# 0       DQRA0194  <data>.apply(lambda x: x[cde] in <#>catalog<#>...
# 1      DQRAI0094  <data>[[cde]].apply(lambda x: True if (x[cde]....
# 2       DQRC0001  <data>.apply(lambda x: (not pd.isnull(x[cde]))...
# 3    DQRC0001_01  <data>.apply(lambda x: (not pd.isnull(x[<#>Col...
# 4    DQRC0001_02  <data>.fillna({<#>bde_risk<#>: ' '}).apply(lam...
# ..           ...                                                ...
# 143     DQRV0023                      <data>[cde].isin(<#>Lista<#>)
# 144   DQRV0023_1            <data>[<#>Column1<#>].isin(<#>Lista<#>)
# 145   DQRV0023_2                     ~<data>[cde].isin(<#>Lista<#>)
# 146     DQRV0024  (( (<data>[cde] == <#>TipoPersona<#>) & (<data...
# 147     DQRV0032                    cde contain specific characters
#
#                                            Description      Category  \
# 0    Ensures that the value in <cde> exists in a sp...      Validity
# 1    Verifies that the value in <cde> starts with a...   Consistency
# 2    Checks that the value in <cde> is not null and...  Completeness
# 3    Similar to DQRC0001 but applies the completene...  Completeness
# 4    Completeness check for <cde>, where missing va...  Completeness
# ..                                                 ...           ...
# 143  Checks if <cde> is part of a specified list (<...      Validity
# 144  Validates that <#>Column1<#> is part of a spec...      Validity
# 145  Ensures that <cde> is not part of a specified ...      Validity
# 146  Ensures that if <cde> equals <#>TipoPersona<#>...         Other
# 147  Validates that <cde> contains specific charact...         Other
#
#                                  Parameters
# 0    ['catalog', 'key', 'Column1', 'Lista']
# 1                             ['startIndx']
# 2                                        []
# 3                    ['Column1', 'Column1']
# 4                              ['bde_risk']
# ..                                      ...
# 143                               ['Lista']
# 144                    ['Column1', 'Lista']
# 145                               ['Lista']
# 146      ['TipoPersona', 'Column1', 'char']
# 147                                      []
#
# [148 rows x 5 columns]

# %%
pd.read_json(path_root / 'data/internim/definitions.json')
# Out:
#       RuleID                                        Description  \
# 0   DQRC0001  Checks that the value in `<cde>` is not null a...
# 1   DQRA0194  Ensures that `<cde>` exists in `<#>catalog<#>`...
# 2   DQRV0020  Compares `<cde>` with `<#>Column1<#>` as dates...
# 3   DQRU0004  Ensures that `<cde>` does not contain duplicat...
# 4   DQRF0005  Validates that the length of the value in `<cd...
# 5   DQRF0037  Applies a regex pattern (`<#>pattern<#>`) to v...
# 6   DQRI0106  Ensures that `<cde>` falls between `<#>Column2...
# 7   DQRC0044  Checks if the value in `<cde>` is non-null and...
# 8   DQRF0006  Ensures that the length of `<cde>` falls betwe...
# 9   DQRF0178  Ensures that `<cde>` does not contain a decima...
# 10  DQRV0014  Ensures that `<cde>` matches a numeric format ...
# 11  DQRV0009  Checks if `<cde>` is present in a catalog (`<#...
# 12  DQRF0030  Validates that `<cde>` contains at least three...
# 13  DQRC0094  Ensures `<cde>` is non-null and non-empty when...
# 14  DQRV0002  Validates that `<cde>` satisfies a numeric com...
# 15  DQRV0023  Checks if `<cde>` is part of a specified list ...
# 16  DQRF0077  Validates that `<cde>` represents a valid date...
# 17  DQRF0037  Validates `<cde>` against a regex pattern (`<#...
# 18  DQRU0127  Ensures `<cde>` does not contain duplicate val...
# 19  DQRV0020  Compares `<cde>` with `<#>Column1<#>` as dates...
# 20  DQRF0175  Ensures `<cde>` does not contain any character...
# 21  DQRI0108  Ensures `<cde>` is strictly greater than `<#>C...
# 22  DQRF0037  Validates `<cde>` against a regex pattern (`<#...
# 23  DQRU0127  Ensures `<cde>` does not contain duplicate val...
# 24  DQRV0020  Compares `<cde>` with `<#>Column1<#>` as dates...
# 25  DQRF0175  Ensures `<cde>` does not contain any character...
# 26  DQRI0108  Ensures `<cde>` is strictly greater than `<#>C...
#
#                                       Condition/Logic  \
# 0   `<cde>` is non-null and contains non-whitespac...
# 1   `<cde>` exists in `<#>catalog<#>` keyed by `<#...
# 2   Parse `<cde>` using `<#>frmtDte1<#>` and `<#>C...
# 3   `<cde>` must not have any duplicate values wit...
# 4   The length of `<cde>` must satisfy `<#>Operato...
# 5   `<cde>` must match the provided `<#>pattern<#>...
# 6   `<cde>` must satisfy `<#>Column2<#> <= <cde> <...
# 7   `<cde>` must be non-null and contain character...
# 8   `<#>length_min<#>` `<#>Operator1<#>` length of...
# 9   The decimal part of `<cde>` must have at most ...
# 10  `<cde>` must match the pattern `\d{1,14}\.\d{2}`.
# 11  `<cde>` must exist in `<#>catalog<#>` keyed by...
# 12  `<cde>` must have at least three consecutive '...
# 13  `<cde>` must not be null or empty if `<#>Colum...
# 14  `<cde>` must satisfy `<#>Operator<#>` `<#>comp...
# 15                  `<cde>` must be in `<#>Lista<#>`.
# 16  `<cde>` must match `YYYYMMDD` format and have ...
# 17   `<cde>` must match the provided `<#>pattern<#>`.
# 18              All values in `<cde>` must be unique.
# 19  `<cde>` and `<#>Column1<#>` must satisfy the c...
# 20  `<cde>` must not contain any character in `<#>...
# 21    `<cde>` must satisfy `<cde>` > `<#>Column2<#>`.
# 22   `<cde>` must match the provided `<#>pattern<#>`.
# 23              All values in `<cde>` must be unique.
# 24  `<cde>` and `<#>Column1<#>` must satisfy the c...
# 25  `<cde>` must not contain any character in `<#>...
# 26    `<cde>` must satisfy `<cde>` > `<#>Column2<#>`.
#
#                                            Parameters  \
# 0   {'<#>ColumnToCheck<#>': 'The column to validat...
# 1   {'<#>ColumnToCheck<#>': 'The column to validat...
# 2   {'<#>ColumnToCheck1<#>': 'The first date colum...
# 3   {'<#>ColumnToCheck<#>': 'The column to validat...
# 4   {'<#>ColumnToCheck<#>': 'The column to validat...
# 5   {'<#>ColumnToCheck<#>': 'The column to validat...
# 6   {'<#>ColumnToCheck<#>': 'The target column to ...
# 7   {'<#>ColumnToCheck<#>': 'The column to validat...
# 8   {'<#>ColumnToCheck<#>': 'The column to validat...
# 9   {'<#>ColumnToCheck<#>': 'The column to validat...
# 10  {'<#>ColumnToCheck<#>': 'The column to validat...
# 11  {'<#>ColumnToCheck<#>': 'The column to validat...
# 12  {'<#>ColumnToCheck<#>': 'The column to validat...
# 13  {'<#>ColumnToCheck<#>': 'The column to validat...
# 14  {'<#>ColumnToCheck<#>': 'The column to validat...
# 15  {'<#>ColumnToCheck<#>': 'The column to validat...
# 16  {'<#>ColumnToCheck<#>': 'The column to validat...
# 17  {'<#>ColumnToCheck<#>': 'The column to validat...
# 18  {'<#>ColumnToCheck<#>': 'The column to validat...
# 19  {'<#>ColumnToCheck<#>': 'The primary column to...
# 20  {'<#>ColumnToCheck<#>': 'The column to validat...
# 21  {'<#>ColumnToCheck<#>': 'The column to validat...
# 22  {'<#>ColumnToCheck<#>': 'The column to validat...
# 23  {'<#>ColumnToCheck<#>': 'The column to validat...
# 24  {'<#>ColumnToCheck<#>': 'The primary column to...
# 25  {'<#>ColumnToCheck<#>': 'The column to validat...
# 26  {'<#>ColumnToCheck<#>': 'The column to validat...
#
#                                               Example  \
# 0   If `<cde>` = `Name` and `Name` = `John`, retur...
# 1   If `<#>DependentColumn<#>`=`VIP` and `<#>ListA...
# 2   If `<#>Operator<#>`=`==` and both dates parse ...
# 3   If `<cde>`=`ID` and `ID`=[1, 2, 3, 3], return ...
# 4   If `<cde>`=`Name` and `<#>Operator<#>`=`>` `<#...
# 5   If `<cde>`=`Code` and `<#>pattern<#>`=`^[A-Z]{...
# 6   If `<cde>`=`Score`=`50`, `<#>Column2<#>`=`40`,...
# 7   If `<cde>`=`Address` and `Address`=`'123 Main ...
# 8   If `<cde>`=`Name`, `<#>length_min<#>`=`5`, `<#...
# 9   If `<cde>`=`Amount` and `<#>DecimalComplement<...
# 10  If `<cde>`=`Balance` and `Balance`=`1234567890...
# 11  If `<cde>`=`ProductID`, `<#>catalog<#>` contai...
# 12  If `<cde>`=`Code` and `Code`=`'BAAAC'`, return...
# 13  If `<#>Column1<#>`=`A`, `<#>Lista<#>`=`[A, B]`...
# 14  If `<cde>`=`Score`, `<#>Operator<#>`=`>=`, and...
# 15  If `<cde>`=`Category` and `<#>Lista<#>`=`['A',...
# 16  If `<cde>`=`Date` and `Date`=`'20231215'`, ret...
# 17  If `<cde>`=`Code` and `<#>pattern<#>`=`^[A-Z]{...
# 18  If `<cde>`=`ID` and `ID`=[1, 2, 3, 3], return ...
# 19  If `<cde>`=`'20231215'`, `<#>Column1<#>`=`'202...
# 20  If `<cde>`=`Name` and `<#>Lista<#>`=`['$', '@'...
# 21  If `<cde>`=`Score`=`60` and `<#>Column2<#>`=`5...
# 22  If `<cde>`=`Code` and `<#>pattern<#>`=`^[A-Z]{...
# 23  If `<cde>`=`ID` and `ID`=[1, 2, 3, 3], return ...
# 24  If `<cde>`=`'20231215'`, `<#>Column1<#>`=`'202...
# 25  If `<cde>`=`Name` and `<#>Lista<#>`=`['$', '@'...
# 26  If `<cde>`=`Score`=`60` and `<#>Column2<#>`=`5...
#
#                     Category                             Categorization
# 0               Completeness              Completeness / Non-Null Check
# 1              Catalog Check            Value List / Catalog Membership
# 2                 Date Check            Date Validation and Comparisons
# 3           Uniqueness Check              Uniqueness / Duplicate Checks
# 4               Length Check   Data Type / Numeric / Length Constraints
# 5           Pattern Matching        Pattern Matching / Regex Validation
# 6                Range Check  Conditional Checks Based on Other Columns
# 7               Completeness              Completeness / Non-Null Check
# 8               Length Check   Data Type / Numeric / Length Constraints
# 9         Numeric Validation   Data Type / Numeric / Length Constraints
# 10          Pattern Matching        Pattern Matching / Regex Validation
# 11             Catalog Check            Value List / Catalog Membership
# 12          Pattern Matching        Pattern Matching / Regex Validation
# 13  Conditional Completeness  Conditional Checks Based on Other Columns
# 14        Numeric Validation   Data Type / Numeric / Length Constraints
# 15           List Validation            Value List / Catalog Membership
# 16           Date Validation            Date Validation and Comparisons
# 17          Pattern Matching        Pattern Matching / Regex Validation
# 18          Uniqueness Check              Uniqueness / Duplicate Checks
# 19           Date Validation            Date Validation and Comparisons
# 20      Character Validation                       Data Validity Checks
# 21        Numeric Comparison  Conditional Checks Based on Other Columns
# 22          Pattern Matching        Pattern Matching / Regex Validation
# 23          Uniqueness Check              Uniqueness / Duplicate Checks
# 24           Date Validation            Date Validation and Comparisons
# 25      Character Validation                       Data Validity Checks
# 26        Numeric Comparison  Conditional Checks Based on Other Columns

# %%
# Load the dataset
rules_df = pd.read_excel(path_root / 'data/processed/Bank_of_Rules-refractored.xlsx')

# Step 1: Preprocess the data
def clean_text(text):
    # Remove placeholders and special characters for better text comparison
    return re.sub(r"<#>.*?<#>", "", text).strip()

rules_df['CleanedDescription'] = rules_df['Description'].apply(clean_text)

# Step 2: Generate semantic embeddings for rule descriptions
model = SentenceTransformer('all-MiniLM-L6-v2')
embeddings = model.encode(rules_df['CleanedDescription'].tolist())

# Step 3: Apply DBSCAN clustering on embeddings
dbscan = DBSCAN(eps=0.5, min_samples=2, metric='cosine')
clusters = dbscan.fit_predict(embeddings)

# Step 4: Assign clusters to the DataFrame
rules_df['Cluster'] = clusters

# Step 5: Identify versioned rules by RuleID patterns
def extract_base_rule_id(rule_id):
    return re.sub(r'_\d+$', '', rule_id)

rules_df['BaseRuleID'] = rules_df['RuleID'].apply(extract_base_rule_id)

# Group rules by BaseRuleID for analysis
rules_df['VersionGroup'] = rules_df.groupby('BaseRuleID').ngroup()

# Step 6: Save results for analysis
rules_df.to_csv(path_root / 'data/ClusteredAndGroupedRules.csv', index=False)

# Step 7: Optional - Analyze clusters
for cluster_id in sorted(rules_df['Cluster'].unique()):
    if cluster_id == -1:
        print("\nUnclustered rules:")
    else:
        print(f"\nCluster {cluster_id}:")
    print(rules_df[rules_df['Cluster'] == cluster_id][['RuleID', 'Description']])
# Out:
# Unclustered rules:
#           RuleID                                        Description
# 113   DQRU0004_1  Removes duplicates from <#>Column1<#>, keeping...
# 132  DQRV0009_03  Ensures that <#>RecordID<#> (converted to floa...
#
# Cluster 0:
#           RuleID                                        Description
# 0       DQRA0194  Ensures that the value in <cde> exists in a sp...
# 1      DQRAI0094  Verifies that the value in <cde> starts with a...
# 2       DQRC0001  Checks that the value in <cde> is not null and...
# 3    DQRC0001_01  Similar to DQRC0001 but applies the completene...
# 4    DQRC0001_02  Completeness check for <cde>, where missing va...
# ..           ...                                                ...
# 143     DQRV0023  Checks if <cde> is part of a specified list (<...
# 144   DQRV0023_1  Validates that <#>Column1<#> is part of a spec...
# 145   DQRV0023_2  Ensures that <cde> is not part of a specified ...
# 146     DQRV0024  Ensures that if <cde> equals <#>TipoPersona<#>...
# 147     DQRV0032  Validates that <cde> contains specific charact...
#
# [146 rows x 2 columns]
